# %% [markdown]
# # Assignment 14
# **By Sriharsha Velicheti**

# %% [markdown]
# #### 1. What does RGBA stand for?
#
# RGBA stands for Red Green Blue Alpha. It is a color model that represents colors using a combination of red, green, and blue channels, along with an additional alpha channel for transparency. Each channel is represented by an 8-bit value, resulting in 256 possible intensities for each color channel and transparency level.
#
# #### 2. From the Pillow module, how do you get the RGBA value of any images?
#
# To get the RGBA value of an image using the Pillow module, you can use the `getpixel()` method. This method returns a tuple representing the RGBA values of a specific pixel in the image. The RGBA values range from 0 to 255, where 0 represents minimum intensity and 255 represents maximum intensity.
#
# #### 3. What is a box tuple, and how does it work?
#
# In Pillow, a box tuple refers to a tuple of four values representing a rectangular region in an image. The four values are (left, upper, right, lower), where `left` is the x-coordinate of the left edge of the box, `upper` is the y-coordinate of the upper edge of the box, `right` is the x-coordinate of the right edge of the box, and `lower` is the y-coordinate of the lower edge of the box.
#
# The box tuple is used to define regions of interest within an image for various operations such as cropping, resizing, and extracting specific areas. It helps specify the boundaries and dimensions of the desired region in the image.
#
# #### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
#
# To find out the width and height of an Image object in Python using the Pillow module, you can use the `size` attribute. After loading the image using the `Image.open()` function, you can access the `size` attribute of the image object, which returns a tuple containing the width and height values.

# %% [markdown]
# ![dp.jpeg](attachment:dp.jpeg)

# %%
from PIL import Image

# Load the image
image = Image.open(r"C:\Users\sriharsha\Desktop\my folder\dp.jpeg")

# Get the width and height
width, height = image.size

print("Width:", width)
print("Height:", height)
# Out:
# Width: 1200
# Height: 1600

# %% [markdown]
# #### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
#
# To get an Image object for a 100x100 image, excluding the lower-left quarter, you can use the `crop()` method of the Image object. The `crop()` method allows you to extract a rectangular region from the image based on the provided box tuple.

# %%
from PIL import Image



#Image loaded in the previous cell
# Create a box tuple for the region excluding the lower-left quarter
box = (0, 0, 100, 100)  # (left, upper, right, lower)

# Crop the image to the specified region
cropped_image = image.crop(box)

# Display the cropped image
cropped_image.show()

# %%
image.crop(box=(400,400,1000,1000))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x167D2F99610>

# %% [markdown]
# #### 6. After making changes to an Image object, how could you save it as an image file?
#
# To save an Image object as an image file after making changes, you can use the `save()` method of the Image object. The `save()` method allows you to specify the file name and format for the saved image.
#
# Example:
# ```python
# from PIL import Image
#
# # Load the image
# image = Image.open("image.jpg")
#
# # Perform some modifications to the image
#
# # Save the modified image as a new file
# image.save("modified_image.jpg")
# ```

# %% [markdown]
# #### 7. What module contains Pillow’s shape-drawing code?
#
# Pillow's shape-drawing code is contained in the `ImageDraw` module. This module provides classes and functions that allow you to draw various shapes, lines, and text on an Image object. The `ImageDraw` module is part of the Pillow library.
#
# To use the shape-drawing code, you need to import the `ImageDraw` module and create an `ImageDraw` object associated with an Image object. You can then use the methods of the `ImageDraw` object to draw shapes or add text to the image.
#
#
#
# #### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# The `ImageDraw` object, obtained from the `ImageDraw` module, is the object that has drawing methods. This object allows you to draw shapes, lines, and text on an Image object.
#
# To obtain an `ImageDraw` object, you need to import the `ImageDraw` module and create an instance of it by passing the Image object as an argument to the `ImageDraw.Draw()` function.
#
# Example:
# ```python
# from PIL import Image, ImageDraw
#
# # Load the image
# image = Image.open("image.jpg")
#
# # Create an ImageDraw object
# draw = ImageDraw.Draw(image)
#
# # Use the drawing methods of the ImageDraw object
# draw.rectangle([(10, 10), (100, 100)], outline="red")
# draw.line([(50, 50), (150, 150)], fill="blue", width=2)
# draw.text((200, 200), "Hello, Pillow!", fill="green")
#
# # Save the modified image
# image.save("modified_image.jpg")
# ```
#
# By using the `ImageDraw` object, you can draw various shapes and add custom elements to an existing image.

# %%
from PIL import Image, ImageDraw

# Loaded the image

# Create an ImageDraw object
draw = ImageDraw.Draw(image)

# Use the drawing methods to draw shapes or add text
draw.rectangle([(10, 10), (100, 100)], outline="red")
draw.line([(50, 50), (150, 150)], fill="blue", width=2)
draw.text((200, 200), "Hi This is Sriharsha ", fill="green")
# Save the modified image
image.save("modified_image.jpg")

# %% [markdown]
# ![modified_image-2.jpg](attachment:modified_image-2.jpg)
